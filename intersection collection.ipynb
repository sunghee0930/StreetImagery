# %%
# !pip -q install "osmnx>=2.0,<3.0" geopandas scipy scikit-learn pyogrio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 3.5 MB/s eta 0:00:00

# %%
# mount
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
for root, dirs, files in os.walk("/content/drive/MyDrive"):
    for filename in files:
        if "msg_sample_2000_per_puma" in filename.lower():
            print(os.path.join(root, filename))
# Out:
# /content/drive/MyDrive/Copy of msg_sample_2000_per_puma_unique_coords.gsheet

# %%
import os
import re
import pandas as pd
from pathlib import Path

INPUT_CSV = Path(
    "/content/drive/MyDrive/msg_sample_2000_per_puma_unique_coords.csv"
)

print(INPUT_CSV.exists())
# Out:
# True

# %%
import pandas as pd

test = pd.read_csv(INPUT_CSV)

print(test.shape)
print(test.columns.tolist())
display(test.head())
# Out:
# (18000, 4)
# ['point_id', 'pumaid', 'query_lat', 'query_lon']
#    point_id   pumaid  query_lat  query_lon
# 0    582797  2600100  45.826451 -88.058868
# 1    330604  2600100  46.552310 -87.400660
# 2    577280  2600100  46.447274 -90.155680
# 3    388006  2600100  46.563320 -87.416840
# 4    591004  2600100  46.089470 -88.623800

# %%
OUTPUT_DIR = Path(
    "/content/drive/MyDrive/Georgetown run"
)

# %%
from pathlib import Path

script_path = Path(
    "/content/robust_tiled_nearest_intersections_9_pumas.py"
)

print(script_path.exists())
# Out:
# True

# %%
# %run /content/robust_tiled_nearest_intersections_9_pumas.py
# Out:
# OSMnx version: 2.1.0
# Input: /content/drive/MyDrive/msg_sample_2000_per_puma_unique_coords.csv
# Output directory: /content/drive/MyDrive/Georgetown run
# Tile size: 30 km
# Tile buffer: 2.0 km
# Overpass endpoints:
#   - https://overpass-api.de/api
#   - https://overpass.kumi.systems/api
#
# Valid rows: 18,000
# Invalid rows: 0
# Unique point IDs: 18,000
# Unique PUMAs: 9
#
# Rows by PUMA:
# pumaid
# 2600100    2000
# 2600802    2000
# 2601200    2000
# 2601600    2000
# 2601701    2000
# 2601703    2000
# 2602903    2000
# 2603203    2000
# 2603212    2000
#
# Processing 18,000 locations across 9 PUMAs.
#
# ...
# PUMA 1/9: 2600100 (2,000 locations)
# ...
#   Complete PUMA checkpoint found; skipping (2,000 rows).
#
# ...
# PUMA 2/9: 2600802 (2,000 locations)
# ...
#   Occupied tiles: 3
#   Tile 1/3 (x=19, y=157; 146 points)
#       Endpoint 1/2: https://overpass-api.de/api
#       Download attempt 1/2...
#       3,951 candidate nodes; downloaded_graph; 0.3 min
#   Tile 2/3 (x=19, y=158; 1789 points)
# ...
